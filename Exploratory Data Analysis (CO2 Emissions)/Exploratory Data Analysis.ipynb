# %% [markdown]
# ## Exploratory Data Analysis.
#
# Due: Monday, December 24, 2018 23:59 hrs
#
#
# ---

# %% [markdown]
# ## Introduction
#
# This assignment will help you learn working with Pandas and then do the exploratory data analysis. I am using data from two resources [World bank](http://data.worldbank.org/) and  [Gapminder](http://www.gapminder.org).
#
#
# #### Useful libraries for this assignment
#
# * [numpy](http://docs.scipy.org/doc/numpy-dev/user/index.html), for arrays
# * [pandas](http://pandas.pydata.org/), for data frames
# * [matplotlib](http://matplotlib.org/), for plotting
# * [Seaborn](https://seaborn.pydata.org/), for plotting
# * [Plotly](https://plot.ly/), for dynamic plotting
#
#
# ---

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem 1
#
# It is said that the CO2 emissions in the world has increased during the last decades. We are interested in doing a exploratory data analysis to find that if the emissions has increased in various regions like Africa/Latin America/Asia and Europe/NorthAmerica. From [World Bank](http://data.worldbank.org/), download the [CO2 emissions per capita](http://api.worldbank.org/v2/en/indicator/EN.ATM.CO2E.PC?downloadformat=excel) as an excel file.

# %% [markdown]
# #### Problem 1(a)
#
# First load the `metadata-countries` sheet from downloaded excel file into a pandas DataFrame and name this data set as `countries`.  This data set can be found [here](https://github.com/cs109/2014_data/blob/master/countries.csv).

# %%
#your code here
countries = pd.read_csv('https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv?fbclid=IwAR2sxBwWF6QwYrUk1u6hb8oLzEwZzMg00BkPqfUeQndv4cXRjw-Prpbbvrw')
countries = pd.DataFrame(countries)
countries
# Out:
#                               Country         Region
# 0                             Algeria         AFRICA
# 1                              Angola         AFRICA
# 2                               Benin         AFRICA
# 3                            Botswana         AFRICA
# 4                             Burkina         AFRICA
# 5                             Burundi         AFRICA
# 6                            Cameroon         AFRICA
# 7                          Cape Verde         AFRICA
# 8            Central African Republic         AFRICA
# 9                                Chad         AFRICA
# 10                            Comoros         AFRICA
# 11                              Congo         AFRICA
# 12      Congo, Democratic Republic of         AFRICA
# 13                           Djibouti         AFRICA
# 14                              Egypt         AFRICA
# 15                  Equatorial Guinea         AFRICA
# 16                            Eritrea         AFRICA
# 17                           Ethiopia         AFRICA
# 18                              Gabon         AFRICA
# 19                             Gambia         AFRICA
# 20                              Ghana         AFRICA
# 21                             Guinea         AFRICA
# 22                      Guinea-Bissau         AFRICA
# 23                        Ivory Coast         AFRICA
# 24                              Kenya         AFRICA
# 25                            Lesotho         AFRICA
# 26                            Liberia         AFRICA
# 27                              Libya         AFRICA
# 28                         Madagascar         AFRICA
# 29                             Malawi         AFRICA
# ..                                ...            ...
# 164                       Saint Lucia  NORTH AMERICA
# 165  Saint Vincent and the Grenadines  NORTH AMERICA
# 166               Trinidad and Tobago  NORTH AMERICA
# 167                     United States  NORTH AMERICA
# 168                         Australia        OCEANIA
# 169                              Fiji        OCEANIA
# 170                          Kiribati        OCEANIA
# 171                  Marshall Islands        OCEANIA
# 172                        Micronesia        OCEANIA
# 173                             Nauru        OCEANIA
# 174                       New Zealand        OCEANIA
# 175                             Palau        OCEANIA
# 176                  Papua New Guinea        OCEANIA
# 177                             Samoa        OCEANIA
# 178                   Solomon Islands        OCEANIA
# 179                             Tonga        OCEANIA
# 180                            Tuvalu        OCEANIA
# 181                           Vanuatu        OCEANIA
# 182                         Argentina  SOUTH AMERICA
# 183                           Bolivia  SOUTH AMERICA
# 184                            Brazil  SOUTH AMERICA
# 185                             Chile  SOUTH AMERICA
# 186                          Colombia  SOUTH AMERICA
# 187                           Ecuador  SOUTH AMERICA
# 188                            Guyana  SOUTH AMERICA
# 189                          Paraguay  SOUTH AMERICA
# 190                              Peru  SOUTH AMERICA
# 191                          Suriname  SOUTH AMERICA
# 192                           Uruguay  SOUTH AMERICA
# 193                         Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# Clean the countries dataframe to keep only the country and region data field.

# %%
#your code here

# %% [markdown]
# From Downloaded excel file, read `Data` datasheet in pandas DataFrame and name this data set as `emissions`.
#
# **Hint**: Consider using the pandas function `pandas.read_excel()` to read in the .xlsx file directly. Be careful to read 'Data' sheet only.

# %%
#your code here
emissions = pd.read_excel('API_EN.ATM.CO2E.PC_DS2_en_excel_v2_10225098.xls.xls', sheet_name='Data', header=2)
emissions = emissions.rename(columns={'Country Name': 'Country'})
emissions
# Out:
#                                                Country Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# 13                                          Azerbaijan          AZE
# 14                                             Burundi          BDI
# 15                                             Belgium          BEL
# 16                                               Benin          BEN
# 17                                        Burkina Faso          BFA
# 18                                          Bangladesh          BGD
# 19                                            Bulgaria          BGR
# 20                                             Bahrain          BHR
# 21                                        Bahamas, The          BHS
# 22                              Bosnia and Herzegovina          BIH
# 23                                             Belarus          BLR
# 24                                              Belize          BLZ
# 25                                             Bermuda          BMU
# 26                                             Bolivia          BOL
# 27                                              Brazil          BRA
# 28                                            Barbados          BRB
# 29                                   Brunei Darussalam          BRN
# ..                                                 ...          ...
# 234  Latin America & the Caribbean (IDA & IBRD coun...          TLA
# 235                                        Timor-Leste          TLS
# 236  Middle East & North Africa (IDA & IBRD countries)          TMN
# 237                                              Tonga          TON
# 238                            South Asia (IDA & IBRD)          TSA
# 239          Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 240                                Trinidad and Tobago          TTO
# 241                                            Tunisia          TUN
# 242                                             Turkey          TUR
# 243                                             Tuvalu          TUV
# 244                                           Tanzania          TZA
# 245                                             Uganda          UGA
# 246                                            Ukraine          UKR
# 247                                Upper middle income          UMC
# 248                                            Uruguay          URY
# 249                                      United States          USA
# 250                                         Uzbekistan          UZB
# 251                     St. Vincent and the Grenadines          VCT
# 252                                      Venezuela, RB          VEN
# 253                             British Virgin Islands          VGB
# 254                              Virgin Islands (U.S.)          VIR
# 255                                            Vietnam          VNM
# 256                                            Vanuatu          VUT
# 257                                              World          WLD
# 258                                              Samoa          WSM
# 259                                             Kosovo          XKX
# 260                                        Yemen, Rep.          YEM
# 261                                       South Africa          ZAF
# 262                                             Zambia          ZMB
# 263                                           Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code       1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.046060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.097472
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.258195
# 4    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 5    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.643689
# 6    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.118758
# 7    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.367473
# 8    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 9    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 10   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.662643
# 11   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   8.582937
# 12   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.373319
# 13   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 14   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 15   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   9.941594
# 16   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.066354
# 17   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.009112
# 18   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 19   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.833901
# 20   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.544478
# 21   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.749763
# 22   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 23   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 24   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.477972
# 25   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.551374
# 26   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.272038
# 27   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.649631
# 28   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.746297
# 29   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.082170
# ..                                      ...             ...        ...
# 234  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.295894
# 235  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 236  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.860176
# 237  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.178585
# 238  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.243930
# 239  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.551595
# 240  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.042583
# 241  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.413565
# 242  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.612272
# 243  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 244  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.082261
# 245  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.062123
# 246  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 247  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.682250
# 248  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.701583
# 249  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  15.999779
# 250  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 251  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135900
# 252  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   7.005105
# 253  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 254  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 255  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.229309
# 256  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 257  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.099013
# 258  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135007
# 259  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 260  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.702611
# 261  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   5.610092
# 262  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 263  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
#
#           1961       1962       1963       1964       1965  ...        2008  \
# 0          NaN        NaN        NaN        NaN        NaN  ...   26.230847
# 1     0.053604   0.073765   0.074233   0.086292   0.101467  ...    0.154101
# 2     0.079038   0.201289   0.192535   0.201003   0.191528  ...    1.181527
# 3     1.374186   1.439956   1.181681   1.111742   1.166099  ...    1.484311
# 4          NaN        NaN        NaN        NaN        NaN  ...    6.427887
# 5     0.685151   0.760855   0.874941   0.999098   1.165705  ...    4.390401
# 6     0.108837   0.163018   0.175223   0.132355   0.146327  ...   22.823947
# 7     2.442616   2.522392   2.316356   2.538379   2.641714  ...    4.682912
# 8          NaN        NaN        NaN        NaN        NaN  ...    1.911538
# 9          NaN        NaN        NaN        NaN        NaN  ...         NaN
# 10    0.849084   1.796794   1.446821   1.540135   2.473585  ...    5.194500
# 11    8.641569   8.835688   9.226440   9.759073  10.622321  ...   18.160876
# 12    4.496362   4.755362   5.155194   5.391004   5.252197  ...    8.295096
# 13         NaN        NaN        NaN        NaN        NaN  ...    4.051383
# 14         NaN   0.015207   0.016160   0.015833   0.011914  ...    0.023219
# 15   10.103872  10.641190  11.386929  11.053655  11.141656  ...    9.751985
# 16    0.052049   0.054209   0.047589   0.055304   0.057115  ...    0.507237
# 17    0.018730   0.017003   0.017504   0.021575   0.019841  ...    0.130557
# 18         NaN        NaN        NaN        NaN        NaN  ...    0.332728
# 19    3.269920   3.835892   4.259781   5.262988   5.645652  ...    6.772088
# 20   10.549281   9.191644   6.710688   8.742076   6.554119  ...   26.708212
# 21    4.746699   5.996432   5.558111   8.118536   9.399610  ...    4.290906
# 22         NaN        NaN        NaN        NaN        NaN  ...    5.354936
# 23         NaN        NaN        NaN        NaN        NaN  ...    6.623164
# 24    0.387211   0.715446   0.622369   0.818296   0.794778  ...    1.425287
# 25    3.868484   3.383712   3.151929   4.124438   3.586487  ...    9.943759
# 26    0.276621   0.286626   0.310160   0.371216   0.371151  ...    1.378966
# 27    0.661771   0.701236   0.705321   0.698987   0.675447  ...    2.008670
# 28    0.838884   1.119401   0.816330   0.766085   0.872450  ...    5.844583
# 29    3.555785   4.137439   3.801178   3.485314   3.257964  ...   24.046884
# ..         ...        ...        ...        ...        ...  ...         ...
# 234   1.296436   1.330875   1.300737   1.367774   1.378542  ...    2.862069
# 235        NaN        NaN        NaN        NaN        NaN  ...    0.187073
# 236   0.842079   0.850526   0.905789   0.995173   1.141337  ...    3.770655
# 237   0.172578   0.166030   0.159423   0.153309   0.147938  ...    1.174807
# 238   0.257095   0.277123   0.292906   0.281716   0.302418  ...    1.134883
# 239   0.563564   0.569603   0.582913   0.624394   0.676140  ...    0.908547
# 240   5.318116   8.225533   1.466687   4.201760   5.694917  ...   33.743586
# 241   0.417262   0.417563   0.444801   0.618485   0.542143  ...    2.385393
# 242   0.616880   0.750244   0.767638   0.870791   0.884282  ...    4.031512
# 243        NaN        NaN        NaN        NaN        NaN  ...    1.063926
# 244   0.067872   0.071734   0.072967   0.091197   0.099494  ...    0.141951
# 245   0.058093   0.059258   0.057791   0.063435   0.078241  ...    0.100755
# 246        NaN        NaN        NaN        NaN        NaN  ...    6.723650
# 247   1.385467   1.260818   1.262008   1.294995   1.367538  ...    5.527812
# 248   1.602724   1.540657   1.639284   1.710099   2.049518  ...    2.466682
# 249  15.681256  16.013937  16.482762  16.968119  17.451725  ...   18.461764
# 250        NaN        NaN        NaN        NaN        NaN  ...    4.538018
# 251   0.133927   0.132214   0.174273   0.215531   0.170618  ...    2.082664
# 252   6.136885   6.155058   6.155746   5.973228   6.187253  ...    6.364740
# 253        NaN   0.441914   0.433862   0.850122   0.832085  ...    6.301672
# 254        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 255   0.237229   0.269494   0.255299   0.320829   0.347716  ...    1.360812
# 256        NaN   0.594871   0.471714   0.864247   0.641697  ...    0.423103
# 257   3.069727   3.140511   3.244499   3.360596   3.439099  ...    4.756160
# 258   0.163532   0.158350   0.184023   0.208092   0.230869  ...    0.979060
# 259        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 260   0.506779   0.726302   0.535971   0.655561   0.696540  ...    0.999238
# 261   5.703690   5.747719   5.811157   6.163809   6.431587  ...    9.854219
# 262        NaN        NaN        NaN   0.949422   1.099048  ...    0.165936
# 263        NaN        NaN        NaN   1.047748   1.182364  ...    0.573101
#
#           2009       2010       2011       2012       2013       2014  2015  \
# 0    25.915833  24.670529  24.505835  13.155542   8.351294   8.408363   NaN
# 245   0.103167   0.115583   0.121524   0.112110   0.129675   0.134656   NaN
# 246   5.647810   6.641350   6.265962   6.487603   5.976642   5.020747   NaN
# 247   5.599058   5.982706   6.403581   6.555614   6.605490   6.588135   NaN
# 248   2.396864   1.893043   2.292942   2.559620   2.226236   1.973151   NaN
# 249  17.157738  17.442166  16.973456  16.304287  16.314352  16.490608   NaN
# 250   3.858172   3.647049   3.874801   3.889733   3.417442   3.420723   NaN
# 251   2.852965   2.012716   1.811013   2.314348   1.911992   1.911345   NaN
# 252   6.289128   6.513377   6.001459   6.649233   6.066461   6.025698   NaN
# 253   6.239460   6.330774   6.308591   6.174050   6.057819   6.072834   NaN
# 254        NaN        NaN        NaN        NaN        NaN        NaN   NaN
# 255   1.469013   1.613360   1.701422   1.572338   1.609112   1.803566   NaN
# 256   0.524345   0.512118   0.545795   0.459329   0.420092   0.594993   NaN
# 257   4.656044   4.828069   4.967581   4.996211   4.987739   4.969974   NaN
# 258   1.011854   1.004361   1.074708   1.046640   1.038064   1.029788   NaN
# 259        NaN        NaN        NaN        NaN        NaN        NaN   NaN
# 260   1.069059   0.992602   0.810900   0.749447   0.996885   0.864835   NaN
# 261   9.870597   9.190699   9.004033   8.845033   8.673963   8.980119   NaN
# 262   0.186396   0.194337   0.205911   0.249457   0.261113   0.288271   NaN
# 263   0.405716   0.552146   0.664751   0.529703   0.775564   0.779956   NaN
#
#      2016  2017
# 0     NaN   NaN
# 1     NaN   NaN
# 2     NaN   NaN
# 3     NaN   NaN
# 4     NaN   NaN
# 5     NaN   NaN
# 6     NaN   NaN
# 7     NaN   NaN
# 8     NaN   NaN
# 9     NaN   NaN
# 10    NaN   NaN
# 11    NaN   NaN
# 12    NaN   NaN
# 13    NaN   NaN
# 14    NaN   NaN
# 15    NaN   NaN
# 16    NaN   NaN
# 17    NaN   NaN
# 18    NaN   NaN
# 19    NaN   NaN
# 20    NaN   NaN
# 21    NaN   NaN
# 22    NaN   NaN
# 23    NaN   NaN
# 24    NaN   NaN
# 25    NaN   NaN
# 26    NaN   NaN
# 27    NaN   NaN
# 28    NaN   NaN
# 29    NaN   NaN
# ..    ...   ...
# 234   NaN   NaN
# 235   NaN   NaN
# 236   NaN   NaN
# 237   NaN   NaN
# 238   NaN   NaN
# 239   NaN   NaN
# 240   NaN   NaN
# 241   NaN   NaN
# 242   NaN   NaN
# 243   NaN   NaN
# 244   NaN   NaN
# 245   NaN   NaN
# 246   NaN   NaN
# 247   NaN   NaN
# 248   NaN   NaN
# 249   NaN   NaN
# 250   NaN   NaN
# 251   NaN   NaN
# 252   NaN   NaN
# 253   NaN   NaN
# 254   NaN   NaN
# 255   NaN   NaN
# 256   NaN   NaN
# 257   NaN   NaN
# 258   NaN   NaN
# 259   NaN   NaN
# 260   NaN   NaN
# 261   NaN   NaN
# 262   NaN   NaN
# 263   NaN   NaN
#
# [264 rows x 62 columns]

# %% [markdown]
# Transform the data set to have `years` as the rows and `countries` as the columns. Show the head of this data set when it is loaded.

# %%
#your code here
emissions = emissions.drop(emissions.index[:1], axis = 0)
emissions_trans = emissions.transpose()
emissions_trans.head()
# Out:
#                                                    1    \
# Country                                    Afghanistan
# Country Code                                       AFG
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                         0.0460599
#
#                                                    2    \
# Country                                         Angola
# Country Code                                       AGO
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                         0.0974716
#
#                                                    3    \
# Country                                        Albania
# Country Code                                       ALB
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                           1.25819
#
#                                                    4    \
# Country                                        Andorra
# Country Code                                       AND
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                               NaN
#
#                                                    5    \
# Country                                     Arab World
# Country Code                                       ARB
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                          0.643689
#
#                                                    6    \
# Country                           United Arab Emirates
# Country Code                                       ARE
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                          0.118758
#
#                                                    7    \
# Country                                      Argentina
# Country Code                                       ARG
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                           2.36747
#
#                                                    8    \
# Country                                        Armenia
# Country Code                                       ARM
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                               NaN
#
#                                                    9    \
# Country                                 American Samoa
# Country Code                                       ASM
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                               NaN
#
#                                                    10   \
# Country                            Antigua and Barbuda
# Country Code                                       ATG
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                          0.662643
#
#                                  ...                    \
# Country                          ...
# Country Code                     ...
# Indicator Name                   ...
# Indicator Code                   ...
# 1960                             ...
#
#                                                    254  \
# Country                          Virgin Islands (U.S.)
# Country Code                                       VIR
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                               NaN
#
#                                                    255  \
# Country                                        Vietnam
# Country Code                                       VNM
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                          0.229309
#
#                                                    256  \
# Country                                        Vanuatu
# Country Code                                       VUT
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                               NaN
#
#                                                    257  \
# Country                                          World
# Country Code                                       WLD
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                           3.09901
#
#                                                    258  \
# Country                                          Samoa
# Country Code                                       WSM
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                          0.135007
#
#                                                    259  \
# Country                                         Kosovo
# Country Code                                       XKX
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                               NaN
#
#                                                    260  \
# Country                                    Yemen, Rep.
# Country Code                                       YEM
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                          0.702611
#
#                                                    261  \
# Country                                   South Africa
# Country Code                                       ZAF
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                           5.61009
#
#                                                    262  \
# Country                                         Zambia
# Country Code                                       ZMB
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                               NaN
#
#                                                    263
# Country                                       Zimbabwe
# Country Code                                       ZWE
# Indicator Name  CO2 emissions (metric tons per capita)
# Indicator Code                          EN.ATM.CO2E.PC
# 1960                                               NaN
#
# [5 rows x 263 columns]

# %% [markdown]
# #### Problem 1(b)
#
# Plot a histogram to show the distribution of `emissions per capita` across all countries in the world for any given year (e.g. 2010). Try different bin sizes to see if there exits any distribution.

# %%
#your code here

emissions = pd.DataFrame(emissions)
#ax = emissions.plot.hist(bins=12)
#ax


#emissions.hist(column='1995', bins=12)
#emissions.hist(column='1995', bins=100)
emissions.hist(column='1995', bins=500)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001400D8D0>]],
#       dtype=object)

# %% [markdown]
# #### Problem 1(c)
#
# Next, we want to merge the data from two dataframes  `countries` and `emissions` for any given year. Write a function that does this.

# %%
"""
Function
--------
mergeByYear

Returns a merged DataFrame containing the country name,  region and CO2 emissions, 
for a given year. 

Parameters
----------
year : int
    The year of interest

Returns
-------
a DataFrame
   A pandas DataFrame with three columns titled 
   'Country', 'Region', and 'CO2 emissions'. 

Example
-------
>>> mergeByYear(2012)
"""

#your code here

def mergeByYear(y):
    result = pd.merge(countries, emissions, on=['Country'])
    #print result.columns
    y = str(y)
    print result[[y, 'Country', 'Region','Indicator Name']]
    
mergeByYear(1982)
# Out:
#           1982                   Country         Region  \
# 0     1.908557                   Algeria         AFRICA
# 1     0.485252                    Angola         AFRICA
# 2     0.125105                     Benin         AFRICA
# 8    CO2 emissions (metric tons per capita)
# 9    CO2 emissions (metric tons per capita)
# 10   CO2 emissions (metric tons per capita)
# 11   CO2 emissions (metric tons per capita)
# 12   CO2 emissions (metric tons per capita)
# 13   CO2 emissions (metric tons per capita)
# 14   CO2 emissions (metric tons per capita)
# 15   CO2 emissions (metric tons per capita)
# 16   CO2 emissions (metric tons per capita)
# 17   CO2 emissions (metric tons per capita)
# 18   CO2 emissions (metric tons per capita)
# 19   CO2 emissions (metric tons per capita)
# 20   CO2 emissions (metric tons per capita)
# 21   CO2 emissions (metric tons per capita)
# 22   CO2 emissions (metric tons per capita)
# 23   CO2 emissions (metric tons per capita)
# 24   CO2 emissions (metric tons per capita)
# 25   CO2 emissions (metric tons per capita)
# 26   CO2 emissions (metric tons per capita)
# 27   CO2 emissions (metric tons per capita)
# 28   CO2 emissions (metric tons per capita)
# 29   CO2 emissions (metric tons per capita)
# ..                                      ...
# 137  CO2 emissions (metric tons per capita)
# 138  CO2 emissions (metric tons per capita)
# 139  CO2 emissions (metric tons per capita)
# 140  CO2 emissions (metric tons per capita)
# 141  CO2 emissions (metric tons per capita)
# 142  CO2 emissions (metric tons per capita)
# 143  CO2 emissions (metric tons per capita)
# 144  CO2 emissions (metric tons per capita)
# 145  CO2 emissions (metric tons per capita)
# 146  CO2 emissions (metric tons per capita)
# 147  CO2 emissions (metric tons per capita)
# 148  CO2 emissions (metric tons per capita)
# 149  CO2 emissions (metric tons per capita)
# 150  CO2 emissions (metric tons per capita)
# 151  CO2 emissions (metric tons per capita)
# 152  CO2 emissions (metric tons per capita)
# 153  CO2 emissions (metric tons per capita)
# 154  CO2 emissions (metric tons per capita)
# 155  CO2 emissions (metric tons per capita)
# 156  CO2 emissions (metric tons per capita)
# 157  CO2 emissions (metric tons per capita)
# 158  CO2 emissions (metric tons per capita)
# 159  CO2 emissions (metric tons per capita)
# 160  CO2 emissions (metric tons per capita)
# 161  CO2 emissions (metric tons per capita)
# 162  CO2 emissions (metric tons per capita)
# 163  CO2 emissions (metric tons per capita)
# 164  CO2 emissions (metric tons per capita)
# 165  CO2 emissions (metric tons per capita)
# 166  CO2 emissions (metric tons per capita)
#
# [167 rows x 4 columns]

# %% [markdown]
# #### Problem 1(d)
#
# Use exploratory data analysis tools such as histograms and boxplots to explore the distribution of the CO2 emissions per person by region data set from 1(c) for a given year. Describe how these change through the recent years?
#
# **Hint**: Use a `for` loop to consider multiple years like for decade use 10 as a step.

# %%
#your code here

# %% [markdown]
# #### Problem 1(e)
#
# Read the [Income per person](https://docs.google.com/spreadsheets/d/1PybxH399kK6OjJI4T2M33UsLqgutwj3SuYbk7Yt6sxE/pub?gid=0) data in `income' dataframe.

# %%
#your code here

url="https://docs.google.com/spreadsheets/d/1PybxH399kK6OjJI4T2M33UsLqgutwj3SuYbk7Yt6sxE/pub?gid=0"
income = pd.read_html(url, header=1)
income = income[0]

income = income.drop(income.index[:0], axis = 0)
income
# Out:
#          1            GDP per capita  Unnamed: 2    1800    1801    1802  \
# 0      NaN                       NaN         NaN     NaN     NaN     NaN
# 1      2.0                  Abkhazia         NaN     NaN     NaN     NaN
# 2      3.0               Afghanistan         NaN   603.0   603.0   603.0
# 3      4.0     Akrotiri and Dhekelia         NaN     NaN     NaN     NaN
# 4      5.0                   Albania         NaN   667.0   667.0   668.0
# 5      6.0                   Algeria         NaN   716.0   716.0   717.0
# 6      7.0            American Samoa         NaN     NaN     NaN     NaN
# 7      8.0                   Andorra         NaN  1197.0  1199.0  1201.0
# 8      9.0                    Angola         NaN   618.0   620.0   623.0
# 9     10.0                  Anguilla         NaN     NaN     NaN     NaN
# 10    11.0       Antigua and Barbuda         NaN   757.0   757.0   757.0
# 11    12.0                 Argentina         NaN  1507.0  1508.0  1508.0
# 12    13.0                   Armenia         NaN   514.0   514.0   514.0
# 13    14.0                     Aruba         NaN   833.0   833.0   833.0
# 14    15.0                 Australia         NaN   815.0   816.0   818.0
# 15    16.0                   Austria         NaN  1848.0  1855.0  1863.0
# 16    17.0                Azerbaijan         NaN   775.0   775.0   775.0
# 17    18.0                   Bahamas         NaN  1445.0  1445.0  1445.0
# 18    19.0                   Bahrain         NaN  1235.0  1240.0  1246.0
# 19    20.0                Bangladesh         NaN   876.0   876.0   876.0
# 20    21.0                  Barbados         NaN   913.0   914.0   914.0
# 21    22.0                   Belarus         NaN   608.0   608.0   608.0
# 22    23.0                   Belgium         NaN  2412.0  2413.0  2413.0
# 23    24.0                    Belize         NaN   579.0   579.0   579.0
# 24    25.0                     Benin         NaN   597.0   597.0   597.0
# 25    26.0                   Bermuda         NaN  1227.0  1227.0  1228.0
# 26    27.0                    Bhutan         NaN   629.0   629.0   630.0
# 27    28.0                   Bolivia         NaN   854.0   854.0   854.0
# 28    29.0    Bosnia and Herzegovina         NaN   669.0   669.0   669.0
# 29    30.0                  Botswana         NaN   397.0   397.0   397.0
# ..     ...                       ...         ...     ...     ...     ...
# 233  234.0                    Turkey         NaN  1221.0  1221.0  1222.0
# 234  235.0              Turkmenistan         NaN   943.0   944.0   945.0
# 235  236.0  Turks and Caicos Islands         NaN   487.0   487.0   487.0
# 236  237.0                    Tuvalu         NaN   719.0   719.0   719.0
# 237  238.0                    Uganda         NaN   464.0   464.0   464.0
# 238  239.0                   Ukraine         NaN   763.0   764.0   765.0
# 239  240.0      United Arab Emirates         NaN   998.0  1001.0  1005.0
# 240  241.0            United Kingdom         NaN  3431.0  3439.0  3450.0
# 241  242.0             United States         NaN  2128.0  2168.0  2203.0
# 242  243.0                   Uruguay         NaN  1758.0  1758.0  1758.0
# 243  244.0                      USSR         NaN     NaN     NaN     NaN
# 244  245.0                Uzbekistan         NaN   502.0   502.0   502.0
# 245  246.0          Wallis et Futuna         NaN     NaN     NaN     NaN
# 246  247.0                   Vanuatu         NaN   585.0   586.0   586.0
# 247  248.0                 Venezuela         NaN   682.0   682.0   682.0
# 248  249.0        West Bank and Gaza         NaN  1220.0  1221.0  1221.0
# 249  250.0              West Germany         NaN     NaN     NaN     NaN
# 250  251.0            Western Sahara         NaN     NaN     NaN     NaN
# 251  252.0                   Vietnam         NaN   861.0   861.0   861.0
# 252  253.0     Virgin Islands (U.S.)         NaN     NaN     NaN     NaN
# 253  254.0      North Yemen (former)         NaN     NaN     NaN     NaN
# 254  255.0      South Yemen (former)         NaN     NaN     NaN     NaN
# 255  256.0                     Yemen         NaN   877.0   879.0   882.0
# 256  257.0                Yugoslavia         NaN     NaN     NaN     NaN
# 257  258.0                    Zambia         NaN   663.0   665.0   667.0
# 258  259.0                  Zimbabwe         NaN   869.0   870.0   871.0
# 259  260.0                     Åland         NaN     NaN     NaN     NaN
# 260  261.0               South Sudan         NaN   507.0   507.0   507.0
# 261  262.0                       NaN         NaN     NaN     NaN     NaN
# 262  263.0                       NaN         NaN     NaN     NaN     NaN
#
#        1803    1804    1805    1806   ...        2006     2007     2008  \
# 0       NaN     NaN     NaN     NaN   ...         NaN      NaN      NaN
# 1       NaN     NaN     NaN     NaN   ...         NaN      NaN      NaN
# 2     603.0   603.0   603.0   603.0   ...      1173.0   1298.0   1311.0
# 3       NaN     NaN     NaN     NaN   ...         NaN      NaN      NaN
# 4     668.0   668.0   668.0   668.0   ...      7476.0   7977.0   8644.0
# 5     718.0   719.0   720.0   721.0   ...     12088.0  12289.0  12314.0
# 6       NaN     NaN     NaN     NaN   ...         NaN      NaN      NaN
# 7    1204.0  1206.0  1208.0  1210.0   ...     42738.0  43442.0  41426.0
# 8     626.0   628.0   631.0   634.0   ...      5445.0   6453.0   7103.0
# 9       NaN     NaN     NaN     NaN   ...         NaN      NaN      NaN
# 10    757.0   757.0   757.0   757.0   ...     24016.0  26008.0  25736.0
# 11   1508.0  1508.0  1508.0  1509.0   ...     12913.0  13873.0  14646.0
# 12    514.0   514.0   514.0   514.0   ...      6020.0   6877.0   7383.0
# 13    833.0   833.0   833.0   833.0   ...     40209.0  40558.0  38594.0
# 14    820.0   822.0   824.0   826.0   ...     39416.0  40643.0  41312.0
# 15   1870.0  1878.0  1885.0  1893.0   ...     42036.0  43418.0  43952.0
# 16    775.0   775.0   776.0   776.0   ...     10711.0  13243.0  14365.0
# 17   1446.0  1446.0  1446.0  1446.0   ...     25530.0  25412.0  24373.0
# 18   1251.0  1256.0  1262.0  1267.0   ...     43358.0  43251.0  42507.0
# 19    876.0   876.0   876.0   876.0   ...      2038.0   2158.0   2265.0
# 20    914.0   914.0   914.0   914.0   ...     15913.0  16099.0  16075.0
# 21    609.0   609.0   609.0   610.0   ...     12010.0  13103.0  14488.0
# 22   2413.0  2414.0  2414.0  2414.0   ...     40661.0  41575.0  41641.0
# 23    579.0   579.0   579.0   579.0   ...      8360.0   8240.0   8293.0
# 24    597.0   597.0   597.0   597.0   ...      1592.0   1616.0   1646.0
# 25   1228.0  1228.0  1228.0  1228.0   ...     58785.0  60117.0  60676.0
# 26    630.0   630.0   630.0   630.0   ...      4767.0   5507.0   5663.0
# 27    854.0   854.0   854.0   854.0   ...      4716.0   4850.0   5066.0
# 28    669.0   669.0   669.0   669.0   ...      8242.0   8820.0   9316.0
# 29    397.0   397.0   398.0   398.0   ...     12241.0  13170.0  13858.0
aN    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 259  26.67  26.67  ...    55.50  55.60  55.80  56.00  55.90  56.00  56.00
#
#       2014   2015   2016
# 0      NaN    NaN    NaN
# 1    54.90  53.80  52.72
# 2      NaN    NaN    NaN
# 3    77.90  78.00  78.10
# 4    76.30  76.40  76.50
# 5    72.80  72.90  73.00
# 6    84.80  84.80  84.80
# 7    59.20  59.60  60.00
# 8      NaN    NaN    NaN
# 9    76.30  76.40  76.50
# 10   76.30  76.50  76.70
# 11   74.50  74.70  74.90
# 12   75.59  75.72  75.85
# 13   82.30  82.30  82.30
# 14   81.20  81.30  81.40
# 15   72.50  72.90  73.30
# 16   73.50  73.70  73.90
# 17   79.10  79.10  79.10
# 18   70.10  70.40  70.70
# 19   75.60  75.70  75.80
# 20   70.70  71.00  71.30
# 21   80.50  80.50  80.50
# 22   71.50  71.70  71.90
# 23   62.00  62.30  62.60
# 24   78.40  78.50  78.60
# 25   72.40  72.70  73.00
# 26   72.90  73.20  73.50
# 27   78.70  78.90  79.10
# 28   57.30  58.70  60.13
# 29   74.30  74.40  74.50
# ..     ...    ...    ...
# 230  72.30  72.40  72.50
# 231  77.60  77.60  77.60
# 232  79.10  79.20  79.30
# 233  69.60  70.00  70.40
# 234    NaN    NaN    NaN
# 235    NaN    NaN    NaN
# 236  60.70  61.30  61.91
# 237  71.30  71.50  71.70
# 238  75.40  75.40  75.40
# 239  80.90  81.00  81.10
# 240  79.10  79.10  79.10
# 241  76.60  76.80  77.00
# 242    NaN    NaN    NaN
# 243  71.50  71.80  72.10
# 244    NaN    NaN    NaN
# 245  64.70  64.90  65.10
# 246  74.80  74.80  74.80
# 247  74.50  74.60  74.70
# 248    NaN    NaN    NaN
# 249  68.04  68.30  68.56
# 250  75.20  75.40  75.60
# 251  80.38  80.60  80.82
# 252    NaN    NaN    NaN
# 253    NaN    NaN    NaN
# 254  67.10  66.00  64.92
# 255    NaN    NaN    NaN
# 256  56.30  56.70  57.10
# 257  57.00  59.30  61.69
# 258    NaN    NaN    NaN
# 259  56.10  56.10  56.10
#
# [260 rows x 219 columns]

# %% [markdown]
# Write a function similar to written in 1(c), that merges income and Life_exp dataframes, such that if you pass a year as argument, it returns
#
# Country, Regions, CO2 emissions, income per capita, life expectency

# %%
#your code here

def mergeByYear(y):
    result1 = pd.merge(income, Life_exp)
    result1

    final_res = pd.merge(result,result1)
    #print final_res
    y = str(y)
    print final_res[[y,'Country', 'Region','Indicator Name','income per capita', 'Life expectancy']]

mergeByYear(1982)
# Out:
# Index([              u'1',  u'GDP per capita',      u'Unnamed: 2',
#                   u'1800',            u'1801',            u'1802',
#                   u'1803',            u'1804',            u'1805',
#                   u'1806',
#        ...
#                   u'2008',            u'2009',            u'2010',
#                   u'2011',            u'2012',            u'2013',
#                   u'2014',            u'2015', u'Life expectancy',
#                   u'2016'],
#       dtype='object', length=221)
# "\ndef mergeByYear(y):\n    result = pd.merge(income, Life_exp)\n    y = str(y)\n    print result[[y, 'Country', 'Region','Indicator Name']]\n    \nmergeByYear(1982)\n"

# %% [markdown]
# Make a plot by getting data from the above function similar to given as below
#
# <img src="CO2-emissions-tons-per-person.PNG" />
#
# where each circle shows a country and size of the circle shows its CO2 emissions. You may use `matplotlib, seaborn or plotly` for this purpose

# %%
#your code here

# %% [markdown]
# ## Discussion for Problem 1
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---
